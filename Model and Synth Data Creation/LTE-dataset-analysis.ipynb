# %%
import pandas as pd
import numpy as np
import warnings
import seaborn as sns
import matplotlib.pyplot as plt
import tensorflow as tf
sns.set(style='whitegrid', context='notebook')
import random as rn
import statistics
# Out:
# 2023-02-08 11:50:53.592104: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 AVX512F AVX512_VNNI FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-02-08 11:50:53.753385: I tensorflow/core/util/util.cc:169] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2023-02-08 11:50:53.759558: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcudart.so.11.0'; dlerror: libcudart.so.11.0: cannot open shared object file: No such file or directory
# ...

# %%
from IPython.display import Image
  
# get the image
Image(url="root_causes_numbers.png", width=600, height=300)
# Out:
# <img src="root_causes_numbers.png" width="600" height="300"/>

# %%
df = pd.read_csv("db_fm_training.txt")
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 550 entries, 0 to 549
# Data columns (total 8 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Retainability  550 non-null    float64
#  1   HOSR           550 non-null    float64
#  2   RSRP           550 non-null    float64
#  3   RSRQ           550 non-null    float64
#  4   SINR           550 non-null    float64
#  5   Throughput     550 non-null    float64
#  6   Distance       550 non-null    float64
#  7   FaultCause     550 non-null    float64
# dtypes: float64(8)
# memory usage: 34.5 KB

# %%
normal_df = df.loc[df['FaultCause'] == 7]

#RSRP
rsrp_mean = statistics.mean(normal_df["RSRP"])
rsrp_std = statistics.stdev(normal_df["RSRP"])

#RSRQ
rsrq_mean = statistics.mean(normal_df["RSRQ"])
rsrq_std = statistics.stdev(normal_df["RSRQ"])

#SINR
sinr_mean = statistics.mean(normal_df["SINR"])
sinr_std = statistics.stdev(normal_df["SINR"])

#Throughput
throughput_mean = statistics.mean(normal_df["Throughput"])
throughput_std = statistics.stdev(normal_df["Throughput"])


print("{} - {}".format(rsrp_mean,rsrp_std))
print("{} - {}".format(rsrq_mean,rsrq_std))
print("{} - {}".format(sinr_mean,sinr_std))
print("{} - {}".format(throughput_mean,throughput_std))
# Out:
# -71.82571929824562 - 2.007135160913281
# -18.133027568922305 - 0.25069134908164764
# 14.854411027568922 - 0.8323093389221232
# 119.09539097744361 - 13.141634259006995

# %%
tlho_df = df.loc[df['FaultCause'] == 4]

#RSRP
rsrp_mean = statistics.mean(tlho_df["RSRP"])
rsrp_std = statistics.stdev(tlho_df["RSRP"])

#RSRQ
rsrq_mean = statistics.mean(tlho_df["RSRQ"])
rsrq_std = statistics.stdev(tlho_df["RSRQ"])

#SINR
sinr_mean = statistics.mean(tlho_df["SINR"])
sinr_std = statistics.stdev(tlho_df["SINR"])

#Throughput
throughput_mean = statistics.mean(normal_df["Throughput"])
throughput_std = statistics.stdev(normal_df["Throughput"])

print("{} - {}".format(rsrp_mean,rsrp_std))
print("{} - {}".format(rsrq_mean,rsrq_std))
print("{} - {}".format(sinr_mean,sinr_std))
print("{} - {}".format(throughput_mean,throughput_std))
# Out:
# -72.30217647058824 - 1.6011304618279008
# -19.010823529411766 - 0.4369024210166337
# 14.580382352941177 - 0.9886263201489558
# 119.09539097744361 - 13.141634259006995

# %%
ii_df = df.loc[df['FaultCause'] == 3]

#RSRP
rsrp_mean = statistics.mean(ii_df["RSRP"])
rsrp_std = statistics.stdev(ii_df["RSRP"])

#RSRQ
rsrq_mean = statistics.mean(ii_df["RSRQ"])
rsrq_std = statistics.stdev(ii_df["RSRQ"])

#SINR
sinr_mean = statistics.mean(ii_df["SINR"])
sinr_std = statistics.stdev(ii_df["SINR"])

#Throughput
throughput_mean = statistics.mean(normal_df["Throughput"])
throughput_std = statistics.stdev(normal_df["Throughput"])

print("{} - {}".format(rsrp_mean,rsrp_std))
print("{} - {}".format(rsrq_mean,rsrq_std))
print("{} - {}".format(sinr_mean,sinr_std))
print("{} - {}".format(throughput_mean,throughput_std))
# Out:
# -72.8036 - 2.0407656406358847
# -18.12686666666667 - 0.19265322905849944
# 7.105533333333333 - 1.3965503349665696
# 119.09539097744361 - 13.141634259006995

# %%
pr_df = df.loc[df['FaultCause'] == 6]

#RSRP
rsrp_mean = statistics.mean(pr_df["RSRP"])
rsrp_std = statistics.stdev(pr_df["RSRP"])

#RSRQ
rsrq_mean = statistics.mean(pr_df["RSRQ"])
rsrq_std = statistics.stdev(pr_df["RSRQ"])

#SINR
sinr_mean = statistics.mean(pr_df["SINR"])
sinr_std = statistics.stdev(pr_df["SINR"])

#Throughput
throughput_mean = statistics.mean(normal_df["Throughput"])
throughput_std = statistics.stdev(normal_df["Throughput"])

print("{} - {}".format(rsrp_mean,rsrp_std))
print("{} - {}".format(rsrq_mean,rsrq_std))
print("{} - {}".format(sinr_mean,sinr_std))
print("{} - {}".format(throughput_mean,throughput_std))
# Out:
# -77.27575 - 1.4264013674667833
# -19.130535714285713 - 0.36678275759615675
# 9.814321428571429 - 1.3714593215385287
# 119.09539097744361 - 13.141634259006995
